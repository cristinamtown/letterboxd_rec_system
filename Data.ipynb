# %% [markdown]
# # Letterboxd Scraping

# %%
# Import necessary libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time

# %% [markdown]
# ## Generate Username list
#
# This function generates a list of the users that follow the chosen user. It scrapes up to x number of pages of usernames from Letterboxd.

# %%
def users_list(username, pages_to_scrape):
    '''Returns a list of users that follow the given username, input the number
    of following pages you wish to scrape as an int.'''
    start = time.time()

    # First page of usernames
    html_page = requests.get('https://letterboxd.com/'+ username + '/followers/page/1') 
    soup = BeautifulSoup(html_page.content, 'html.parser')

    # Create list of usernames
    users = [movie.find('a', class_='avatar -a40')['href'] 
             for movie in soup.find_all('div', class_='person-summary')]

    # Add pages 2-pages_to_scrape to list of usernames
    for x in range(2, pages_to_scrape):
        x = str(x)
        html_page = requests.get('https://letterboxd.com/'+ username + '/followers/page/' + x ) 
        soup = BeautifulSoup(html_page.content, 'html.parser')
    
        users = users + [movie.find('a', class_='avatar -a40')['href']
                          for movie in soup.find_all('div', class_='person-summary')]
    
    
    # Add original username to list
    users.append(username)

    # Strip the '/' from the usernames
    users = [elem.strip('/') for elem in users]
    print(f'number of usernames: {len(users)}')

    # Print run time
    end = time.time()
    print(f'time to run: {round((end-start), 2)}')
    return users

# %% [markdown]
# My chosen user is 'fuchsiadyke' due to the fact that they are followed by over 16,000 users ensuring that we will get the 100 full pages of usernames.

# %%
# Run the above function to get the list of usernames
users = users_list('fuchsiadyke', 100)

# %%
# A quick look at the first 10 values in the list
users[0:10]

# %% [markdown]
# ## Generate Rating DataFrame

# %% [markdown]
# The following function takes in a usernames gathers the all the rating information from the movies they have marked as seen on Letterboxd.

# %%
def user_rating_3_col(username):
    '''Scrapes user ratings from Letterboxd.com and creates a dataframe with
    three columns: film_id, username, and rating'''

    # Scrape the first page of films watched by username
    html_page = requests.get('https://letterboxd.com/'+ username + '/films/page/' + '1' )
    soup = BeautifulSoup(html_page.content, 'html.parser')
    # Find the last page number of films watched by usename

    try: 
        pages = soup.find('div', class_="paginate-pages")
        last_page = pages.find_all('li', class_='paginate-page')
        last_page = last_page[-1].text
    except:
        last_page = 1
    

    # Create dictionary of film_id, film_name, and link
    movies = [{'film_id': movie.find('div', class_='film-poster')['data-film-id']} 
              for movie in soup.find_all('li', class_='poster-container')]

    # Create Dataframe with film_id, film_name, link
    df_temp1 = pd.DataFrame(movies)

    
    film_rating = []
    user_rating = []

    # Create list of star rating
    for x in soup.find_all('li', class_='poster-container'):
        try: 
            film_rating.append(x.find('span', class_='rating').text)
        except: 
            film_rating.append(None)

    # Change star rating to number rating        
    for x in film_rating:
        try:
            if x[-1]=='½':
                user_rating.append(len(x)-0.5)
            else:
                user_rating.append(len(x))
        except:
            user_rating.append(None)
            
    # Add user_rating to the df
    df_temp1['rating'] = user_rating
    df_temp1['username'] = username
    
    # Scrape remaining pages and add to Dataframe
    lp = int(last_page)

    for y in range(2, lp+1):
        z = str(y)
    
        html_page2 = requests.get('https://letterboxd.com/'+ username + '/films/page/' + z )
        soup2 = BeautifulSoup(html_page2.content, 'html.parser')
        
        # Create dictionary of film_id, film_name, and link
        movies2 = [{'film_id': movie.find('div', class_='film-poster')['data-film-id']} 
                  for movie in soup2.find_all('li', class_='poster-container')]
        df_temp = pd.DataFrame(movies2)
    
        film_rating2 = []
        user_rating2 = []
        
        # Create list of star rating
        for x in soup2.find_all('li', class_='poster-container'):
            try: 
                film_rating2.append(x.find('span', class_='rating').text)
            except: 
                film_rating2.append(None)

        # Change star rating to number rating        
        for x in film_rating2:
            try:
                if x[-1]=='½':
                    user_rating2.append(len(x)-0.5)
                else:
                    user_rating2.append(len(x))
            except:
                user_rating2.append(None)
            
        # add user_rating to the df
        df_temp['rating'] = user_rating2
        df_temp['username'] = username
        
        
        df_temp1 = df_temp1.append(df_temp)
        
    return df_temp1

# %%
# Create a list of test_users to ensure the function works before running on 
# all usernames

test_users = ['ingloriousbasta', 'eldodo', 'tldr_com', 'yangforyin', 'iutub',
              'willmsfilms', 'rockz', 'cae_des', 'ca2ba2', 'nischal170', 'javidog', 
              'irokill', 'ithacuss', 'ngcaihui42', 'mrireilly', 'danyalahmed',
              'bortex', 'travishenderson', 'manuelcouto', 'sunsetsofie', 'nataliedc',
              'badsioop', 'thewatchmakers', 'tashk', 'redgravehepburn', 'sadfrog23',
              'sargy7', 'kna1223', 'janvite', 'privateidahos', 'mirels', 'dovegirl',
              'adamcbest', 'sergioaudelo', 'muzwot', 'ethanjame', 'tylerharris',
              'bugix', 'stephensboyer', 'kamikazegirls', 'alexisthegay', 'waster', 
              'seymacetin', 'arent', 'panizzz', 'phillitj', 'midnightnostalg', 
              'rkrespin', 'spikeydlux', 'sbernstein9', 'cryptidpeep', 'lenilinden',
              'jomes', 'groenbaek', 'elisabethmcl', 'jasonmcghan', 'lostasterisk', 
              'fridge_lp', 'chiarahp', 'jmitchell67', 'dpen42', 'dubsdeedubs', 
              'piaescobar', 'jgaffney', 'jayhayes05', 'beatrixralph1', 
              'mickeemouser', '12monkeys']

# %%
# A for loop that runs through the list of usernames and the previous function
# to create a dataframe of their ratings
start = time.time()

df = pd.DataFrame(columns=['film_id'])

for user in users:
    try:
        temp = user_rating_3_col(user)
        df = df.append(temp)
    except:
        pass

end = time.time()
    
print(f'This took {round((end - start), 2)} seconds to run')

# %%
# Quick look to make sure it work as intended
df.info()

# %%
df.tail()

# %%
# Rearrange the columns into how we will use them in the models.
df = df[['username', 'film_id', 'rating']]

# %%
# Save df as a .csv file
df.to_csv(r'panda_dataframes/user_rating_3col.csv', index = False)

# %%
df.head()

# %% [markdown]
# ## Create DataFrame for Film Information

# %%
def film_names(last_page):
    """Scrapes film names from letterboxd.com. It takes the last_page to
    be scraped as int. It returns a dataframe with the film name, letterboxd link,
    and letterboxd id"""
    
    start = time.time()
    html_page = requests.get('https://letterboxd.com/films/ajax/popular/size/small/page/1/')
    soup = BeautifulSoup(html_page.content, 'html.parser')

    movies = [{'film_name': movie.find('a', class_='frame')['title'], 
               'lb_link': 'https://letterboxd.com' + movie.find('a', class_='frame')['href'],
               'lb_id': movie.find('div')['data-film-id']}
              for movie in soup.find_all('li', class_='listitem poster-container')]

    df_film = pd.DataFrame(movies)


    # Add pages 2-3000 to df_film
    for x in range(2, last_page):
        x = str(x)
        html_page = requests.get('https://letterboxd.com/films/ajax/popular/size/small/page/' + x)
        soup = BeautifulSoup(html_page.content, 'html.parser')
    
        movies = [{'film_name': movie.find('a', class_='frame')['title'], 
                   'lb_link': 'https://letterboxd.com' + movie.find('a', class_='frame')['href'],
                   'lb_id': movie.find('div')['data-film-id']}
                  for movie in soup.find_all('li', class_='listitem poster-container')]

    
        df_temp = pd.DataFrame(movies)
        df_film = df_film.append(df_temp)
    
    end = time.time()
    print(f'This took {round((end - start), 2)} seconds to run')
    
    return df_film

# %%
df_film = film_names(3000)
# Out:
# This took 2.03 seconds to run

# %%
df_film['lb_id'].nunique()
# Out:
# 144

# %%
def add_dir_tmdb(df):
    """Takes the film_names df and scrapes each individual film page to return 
    a data frame with director, tmdb id, and whether it is a movie or tv show."""

    start = time.time()
    
    directors =[]
    tmdb_ids = []
    movie_or_tv = []

    for x in range(0, len(df_film)):
        html = df_film.iloc[x]['lb_link']
        html_page = requests.get(html)
        film = BeautifulSoup(html_page.content, 'html.parser')
        temp = film.find('a', {'data-track-action': 'TMDb'})['href'].split('/')
        movie_tv = temp[-3]
        tmdb = temp[-2]
        temp2 = film.find('div', class_='tabbed-content-block column-block')
        temp2 = temp2.find('a', class_='text-slug').text
        directors.append(temp2)
        tmdb_ids.append(tmdb)
        movie_or_tv.append(movie_tv)
    
    end = time.time()
    
    df_film['director'] = directors
    df_film['tmdb_id'] = tmdb_ids
    df_film['movie_tv'] = movie_or_tv
    
    print(f'This took {round((end - start), 2)} seconds to run')

    return df_film
    # Took 53036.17 seconds to run

# %%
df_film = add_dir_tmdb(df_film)
df_film
# Out:
# This took 97.88 seconds to run
#                                             film_name   lb_id  \
# 0                                     Parasite (2019)  426406
# 1                                        Joker (2019)  406775
# 2                                   Knives Out (2019)  475370
# 3                                 Pulp Fiction (1994)   51444
# 4                                    Inception (2010)   34722
# 5                                      Get Out (2017)  353117
# 6                                    Lady Bird (2017)  326279
# 7               Once Upon a Time… in Hollywood (2019)  397859
# 8            Spider-Man: Into the Spider-Verse (2018)  251943
# 9                                    Midsommar (2019)  459564
# 10                                  Fight Club (1999)   51568
# 11                             The Dark Knight (2008)   51896
# 12                                  La La Land (2016)  240344
# 13                    The Grand Budapest Hotel (2014)   95113
# 14                                Interstellar (2014)  117621
# 15                                 Jojo Rabbit (2019)  444600
# 16                                 Baby Driver (2017)  268950
# 17                                         Her (2013)  114564
# 18                        Inglourious Basterds (2009)   41352
# 19                                 The Shining (1980)   51432
# 20                                    Whiplash (2014)  171384
# 21                               Black Panther (2018)  209383
# 22                     The Wolf of Wall Street (2013)   86114
# 23                      Avengers: Infinity War (2018)  226661
# 24                                  Uncut Gems (2019)  404266
# 25                                   Gone Girl (2014)  149857
# 26                           Avengers: Endgame (2019)  226660
# 27                              The Lighthouse (2019)  433863
# 28                          Mad Max: Fury Road (2015)   62780
# 29                                     Arrival (2016)  257426
# ..                                                ...     ...
# 42                                 The Lobster (2015)  178123
# 43                                Wonder Woman (2017)  225027
# 44                                   The Witch (2015)  237177
# 45  The Lord of the Rings: The Return of the King ...   51928
# 46                           The Hateful Eight (2015)  197012
# 47                             The Incredibles (2004)   46806
# 48                          The Breakfast Club (1985)   50518
# 49                                       Fargo (1996)   51781
# 50                            Moonrise Kingdom (2012)   70105
# 51                                      Psycho (1960)   51578
# 52                            The Big Lebowski (1998)   51935
# 53             The Perks of Being a Wallflower (2012)   71338
# 54                     Avengers: Age of Ultron (2015)   81605
# 55                         The Florida Project (2017)  328538
# 56                                     Titanic (1997)   51524
# 57                                   John Wick (2014)  172076
# 58                               Incredibles 2 (2018)  184061
# 59                                Annihilation (2018)  227784
# 60       The Lord of the Rings: The Two Towers (2002)   51929
# 61    Harry Potter and the Prisoner of Azkaban (2004)   51451
# 62                              A Star Is Born (2018)  261108
# 63                          Return of the Jedi (1983)   50712
# 64                         There Will Be Blood (2007)   48044
# 65                           Good Will Hunting (1997)   51621
# 66                             American Beauty (1999)    2703
# 67                                The Prestige (2006)   51147
# 68                          My Neighbor Totoro (1988)   47756
# 69                                Finding Nemo (2003)    2705
# 70                           Fantastic Mr. Fox (2009)   46344
# 71                                    I, Tonya (2017)  323609
#
#                                               lb_link tmdb_id movie_tv  \
# 0          https://letterboxd.com/film/parasite-2019/  496243    movie
# 1             https://letterboxd.com/film/joker-2019/  475557    movie
# 2        https://letterboxd.com/film/knives-out-2019/  546554    movie
# 3           https://letterboxd.com/film/pulp-fiction/     680    movie
# 4              https://letterboxd.com/film/inception/   27205    movie
# 5           https://letterboxd.com/film/get-out-2017/  419430    movie
# 6              https://letterboxd.com/film/lady-bird/  391713    movie
# 7   https://letterboxd.com/film/once-upon-a-time-i...  466272    movie
# 8   https://letterboxd.com/film/spider-man-into-th...  324857    movie
# 9              https://letterboxd.com/film/midsommar/  530385    movie
# 10            https://letterboxd.com/film/fight-club/     550    movie
# 11       https://letterboxd.com/film/the-dark-knight/     155    movie
# 12            https://letterboxd.com/film/la-la-land/  313369    movie
# 13  https://letterboxd.com/film/the-grand-budapest...  120467    movie
# 14          https://letterboxd.com/film/interstellar/  157336    movie
# 15           https://letterboxd.com/film/jojo-rabbit/  515001    movie
# 16           https://letterboxd.com/film/baby-driver/  339403    movie
# 17                   https://letterboxd.com/film/her/  152601    movie
# 18  https://letterboxd.com/film/inglourious-basterds/   16869    movie
# 19           https://letterboxd.com/film/the-shining/     694    movie
# 20         https://letterboxd.com/film/whiplash-2014/  244786    movie
# 21         https://letterboxd.com/film/black-panther/  284054    movie
# 22  https://letterboxd.com/film/the-wolf-of-wall-s...  106646    movie
# 23  https://letterboxd.com/film/avengers-infinity-...  299536    movie
# 24            https://letterboxd.com/film/uncut-gems/  473033    movie
# 25             https://letterboxd.com/film/gone-girl/  210577    movie
# 26      https://letterboxd.com/film/avengers-endgame/  299534    movie
# 27   https://letterboxd.com/film/the-lighthouse-2019/  503919    movie
# 28     https://letterboxd.com/film/mad-max-fury-road/   76341    movie
# 29          https://letterboxd.com/film/arrival-2016/  329865    movie
# ..                                                ...     ...      ...
# 42           https://letterboxd.com/film/the-lobster/  254320    movie
# 43     https://letterboxd.com/film/wonder-woman-2017/  297762    movie
# 44        https://letterboxd.com/film/the-witch-2015/  310131    movie
# 45  https://letterboxd.com/film/the-lord-of-the-ri...     122    movie
# 46     https://letterboxd.com/film/the-hateful-eight/  273248    movie
# 47       https://letterboxd.com/film/the-incredibles/    9806    movie
# 48    https://letterboxd.com/film/the-breakfast-club/    2108    movie
# 49                 https://letterboxd.com/film/fargo/     275    movie
# 50      https://letterboxd.com/film/moonrise-kingdom/   83666    movie
# 51                https://letterboxd.com/film/psycho/     539    movie
# 52      https://letterboxd.com/film/the-big-lebowski/     115    movie
# 53  https://letterboxd.com/film/the-perks-of-being...   84892    movie
# 54  https://letterboxd.com/film/avengers-age-of-ul...   99861    movie
# 55   https://letterboxd.com/film/the-florida-project/  394117    movie
# 56          https://letterboxd.com/film/titanic-1997/     597    movie
# 57             https://letterboxd.com/film/john-wick/  245891    movie
# 58         https://letterboxd.com/film/incredibles-2/  260513    movie
# 59          https://letterboxd.com/film/annihilation/  300668    movie
# 60  https://letterboxd.com/film/the-lord-of-the-ri...     121    movie
# 61  https://letterboxd.com/film/harry-potter-and-t...     673    movie
# 62   https://letterboxd.com/film/a-star-is-born-2018/  332562    movie
# 63    https://letterboxd.com/film/return-of-the-jedi/    1892    movie
# 64   https://letterboxd.com/film/there-will-be-blood/    7345    movie
# 65     https://letterboxd.com/film/good-will-hunting/     489    movie
# 66       https://letterboxd.com/film/american-beauty/      14    movie
# 67          https://letterboxd.com/film/the-prestige/    1124    movie
# 68    https://letterboxd.com/film/my-neighbor-totoro/    8392    movie
# 69          https://letterboxd.com/film/finding-nemo/      12    movie
# 70      https://letterboxd.com/film/fantastic-mr-fox/   10315    movie
# 71               https://letterboxd.com/film/i-tonya/  389015    movie
#
#                 director
# 0           Bong Joon-ho
# 1          Todd Phillips
# 2           Rian Johnson
# 3      Quentin Tarantino
# 4      Christopher Nolan
# 5           Jordan Peele
# 6           Greta Gerwig
# 7      Quentin Tarantino
# 8         Rodney Rothman
# 9              Ari Aster
# 10         David Fincher
# 11     Christopher Nolan
# 12       Damien Chazelle
# 13          Wes Anderson
# 14     Christopher Nolan
# 15         Taika Waititi
# 16          Edgar Wright
# 17           Spike Jonze
# 18     Quentin Tarantino
# 19       Stanley Kubrick
# 20       Damien Chazelle
# 21          Ryan Coogler
# 22       Martin Scorsese
# 23         Anthony Russo
# 24           Josh Safdie
# 25         David Fincher
# 26         Anthony Russo
# 27         Robert Eggers
# 28         George Miller
# 29      Denis Villeneuve
# ..                   ...
# 42      Yorgos Lanthimos
# 43         Patty Jenkins
# 44         Robert Eggers
# 45         Peter Jackson
# 46     Quentin Tarantino
# 47             Brad Bird
# 48           John Hughes
# 49             Joel Coen
# 50          Wes Anderson
# 51      Alfred Hitchcock
# 52             Joel Coen
# 53       Stephen Chbosky
# 54           Joss Whedon
# 55            Sean Baker
# 56         James Cameron
# 57        Chad Stahelski
# 58             Brad Bird
# 59          Alex Garland
# 60         Peter Jackson
# 61        Alfonso Cuarón
# 62        Bradley Cooper
# 63      Richard Marquand
# 64  Paul Thomas Anderson
# 65          Gus Van Sant
# 66            Sam Mendes
# 67     Christopher Nolan
# 68        Hayao Miyazaki
# 69        Andrew Stanton
# 70          Wes Anderson
# 71       Craig Gillespie
#
# [144 rows x 6 columns]

# %%
# Add year to dataframe

film_ = list(df_film['film_name'])
film_year = [film_[0][-5:-1]]

for x in range(1, len(film_)):
    film_year.append(film_[x][-5:-1])

df_film['release_year'] = film_year

# %%
# Strip year from title

df_film['film_name'] = df_film['film_name'].str[:-7]
df_film.head()

# %%
# Rearrange the columns
df_film = df_film[['film_name', 'lb_id', 'lb_link', 'tmdb_id', 'movie_tv', 'Year', 'Director']]

# %%
# save df_film to computer
df_film.to_csv(r'panda_dataframes/letterboxd_film_data_director.csv', index = False)

# %% [markdown]
# ## Create Individual User DataFrames

# %%
def make_user_df(username):
    start = time.time()
    
    # Scrape the first page of films watched by username
    html_page = requests.get('https://letterboxd.com/'+ username + '/films/page/' + '1' )
    soup = BeautifulSoup(html_page.content, 'html.parser')
    
    # Find the last page number of films watched by usename
    pages = soup.find('div', class_="paginate-pages")
    last_page = pages.find_all('li', class_='paginate-page')
    last_page = last_page[-1].text
    
    # Create dictionary of film_id, film_name, and link
    movies = [{'film_id': movie.find('div', class_='film-poster')['data-film-id'],
          'film_name': movie.find('img', class_='image')['alt'], 
          'link': "https://letterboxd.com" + movie.find('div', class_= 'film-poster')['data-target-link']} 
              for movie in soup.find_all('li', class_='poster-container')]
    
    # Create Dataframe with film_id, film_name, link
    df = pd.DataFrame(movies)
    
    film_rating = []
    user_rating = []

    # Create list of star rating
    for x in soup.find_all('li', class_='poster-container'):
        try: 
            film_rating.append(x.find('span', class_='rating').text)
        except: 
            film_rating.append(None)

    # Change star rating to number rating        
    for x in film_rating:
        try:
            if x[-1]=='½':
                user_rating.append(len(x)-0.5)
            else:
                user_rating.append(len(x))
        except:
            user_rating.append(None)
            
    # Add user_rating to the df
    df['user_rating'] = user_rating
    
    # Scrape remaining pages and add to Dataframe
    lp = int(last_page)
    for y in range(2, lp+1):
        z = str(y)

        html_page2 = requests.get('https://letterboxd.com/'+ username + '/films/page/' + z )
        soup2 = BeautifulSoup(html_page2.content, 'html.parser')
        
        # Create dictionary of film_id, film_name, and link
        movies2 = [{'film_id': movie.find('div', class_='film-poster')['data-film-id'],
              'film_name': movie.find('img', class_='image')['alt'], 
              'link': "https://letterboxd.com" + movie.find('div', class_= 'film-poster')['data-target-link']} 
                  for movie in soup2.find_all('li', class_='poster-container')]
        df_temp = pd.DataFrame(movies2)
    
        film_rating2 = []
        user_rating2 = []
        
        # Create list of star rating
        for x in soup2.find_all('li', class_='poster-container'):
            try: 
                film_rating2.append(x.find('span', class_='rating').text)
            except: 
                film_rating2.append(None)

        # Change star rating to number rating        
        for x in film_rating2:
            try:
                if x[-1]=='½':
                    user_rating2.append(len(x)-0.5)
                else:
                    user_rating2.append(len(x))
            except:
                user_rating2.append(None)
            
        # add user_rating to the df
        df_temp['user_rating'] = user_rating2
        
        
        df = df.append(df_temp, ignore_index=True)
    
    end = time.time()
    
    print(f'This took {round((end - start), 2)} seconds to run')
    
    return df

# %%
# Test for username = creepergnome
creepergnome = make_user_df('creepergnome')
creepergnome.head()
# Out:
# This took 36.14 seconds to run
#   film_id                             film_name  \
# 0  415620                      Coming 2 America
# 1  494480  The United States vs. Billie Holiday
# 2  515466                           Tom & Jerry
# 3  511342           Judas and the Black Messiah
# 4  671813                           WandaVision
#
#                                                 link  user_rating
# 0      https://letterboxd.com/film/coming-2-america/          3.0
# 1  https://letterboxd.com/film/the-united-states-...          3.0
# 2        https://letterboxd.com/film/tom-jerry-2021/          2.0
# 3  https://letterboxd.com/film/judas-and-the-blac...          4.0
# 4           https://letterboxd.com/film/wandavision/          4.0

# %%
creepergnome.loc[creepergnome['film_name']=='Parasite']

# %%
creepergnome.head()

# %%
creepergnome['film_id'].nunique()

# %%
creepergnome.info()

# %%
# # Test for username = rockthrowingman
# rockthrowingman = make_user_df('rockthrowingman')
# rockthrowingman.head()

# %%
# rockthrowingman.tail()

# %%
# rockthrowingman.info()

# %%
# 1000 or so users
# 

# tables => username/ID
# movie info
# Ratings

# %% [markdown]
# # Create SQL Table

# %%
# Open dataframes
df_rating = pd.read_csv('panda_dataframes/user_rating_3col.csv')
df_film = pd.read_csv('panda_dataframes/letterboxd_film_data_director.csv')

# %%
# Double check the columns of both data frames
df_film.columns

# %%
df_rating.columns

# %%
# Inport and create an engine 
from sqlalchemy import create_engine

engine = create_engine('sqlite:///letterboxd.db', echo=True)

# %%
# Create a function that takes the dataframe to make a table in our database
def create_sql_table(df, table_name, engine):
    df.to_sql(table_name, con=engine, if_exists='replace')

# %%
# Add tables to database
create_sql_table(df_rating, 'ratings', engine)

# %%
# Add taable to database
create_sql_table(df_film, 'films', engine)
