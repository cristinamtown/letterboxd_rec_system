# %% [markdown]
# # TMdB API

# %% [markdown]
# This notebook focuses on gathering movie information from the TMdB API. By the end of the notebook, the final dataframe should consist of the following columns: film name, director, letterboxd ID, Letterboxd link, TMdB ID, year, tagline, genres, run time, average rating, overview, and languages.

# %%
# import necessary libraries
import pandas as pd
import tmdbsimple as tmdb

# %%
# Input api key, I am using a path to a txt file to hide the api key
api_key = pd.read_csv('/Users/Crisitna/Desktop/FlatIron/Capstone/api.txt')
api_key = api_key.columns[0]
tmdb.API_KEY = api_key

# %%
# Load dataframe that will add information
film_df = pd.read_csv('panda_dataframes/letterboxd_film_data_director.csv')
print(film_df.info())
film_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71928 entries, 0 to 71927
# Data columns (total 7 columns):
# film_name       71872 non-null object
# lb_id           71928 non-null int64
# lb_link         71928 non-null object
# tmdb_id         71928 non-null int64
# movie_tv        71928 non-null object
# release_year    71927 non-null object
# director        71909 non-null object
# dtypes: int64(2), object(5)
# memory usage: 3.8+ MB
# None
#       film_name   lb_id                                        lb_link  \
# 0      Parasite  426406    https://letterboxd.com//film/parasite-2019/
# 1         Joker  406775       https://letterboxd.com//film/joker-2019/
# 2    Knives Out  475370  https://letterboxd.com//film/knives-out-2019/
# 3  Pulp Fiction   51444     https://letterboxd.com//film/pulp-fiction/
# 4     Inception   34722        https://letterboxd.com//film/inception/
#
#    tmdb_id movie_tv release_year           director
# 0   496243    movie         2019       Bong Joon-ho
# 1   475557    movie         2019      Todd Phillips
# 2   546554    movie         2019       Rian Johnson
# 3      680    movie         1994  Quentin Tarantino
# 4    27205    movie         2010  Christopher Nolan

# %% [markdown]
# We want the final database to have the following columns:  film name, director, letterboxd ID, Letterboxd link, TMdB ID, year, tagline, genres, run time, average rating, overview, and languages.
#
# This means we need still need these columns:

# %%
# A quick look at the data any one movie will contain
movie = tmdb.Movies(496243)

movie.info()
# Out:
# {'adult': False,
#  'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#  'belongs_to_collection': None,
#  'budget': 11363000,
#  'genres': [{'id': 35, 'name': 'Comedy'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 18, 'name': 'Drama'}],
#  'homepage': 'https://www.parasite-movie.com/',
#  'id': 496243,
#  'imdb_id': 'tt6751668',
#  'original_language': 'ko',
#  'original_title': '기생충',
#  'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#  'popularity': 101.267,
#  'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#  'production_companies': [{'id': 4399,
#    'logo_path': '/7bWmbWfxFNSGTCjLHkHn3UjspZS.png',
#    'name': 'Barunson E&A',
#    'origin_country': 'KR'},
#   {'id': 7036,
#    'logo_path': '/javbyY0ZCvlFJtly3tpZqf2NwLX.png',
#    'name': 'CJ Entertainment',
#    'origin_country': 'KR'}],
#  'production_countries': [{'iso_3166_1': 'KR', 'name': 'South Korea'}],
#  'release_date': '2019-05-30',
#  'revenue': 257591776,
#  'runtime': 133,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'German', 'iso_639_1': 'de', 'name': 'Deutsch'},
#   {'english_name': 'Korean', 'iso_639_1': 'ko', 'name': '한국어/조선말'}],
#  'status': 'Released',
#  'tagline': 'Act like you own the place.',
#  'title': 'Parasite',
#  'video': False,
#  'vote_average': 8.5,
#  'vote_count': 11678}

# %%
# Isolating the title
movie.title
# Out:
# 'Parasite'

# %%
# Create a test df to test code before using on larger dataframe
test = film_df[0:50].copy()
test.head()
# Out:
#       film_name   lb_id                                        lb_link  \
# 0      Parasite  426406    https://letterboxd.com//film/parasite-2019/
# 1         Joker  406775       https://letterboxd.com//film/joker-2019/
# 2    Knives Out  475370  https://letterboxd.com//film/knives-out-2019/
# 3  Pulp Fiction   51444     https://letterboxd.com//film/pulp-fiction/
# 4     Inception   34722        https://letterboxd.com//film/inception/
#
#    tmdb_id movie_tv release_year           director
# 0   496243    movie         2019       Bong Joon-ho
# 1   475557    movie         2019      Todd Phillips
# 2   546554    movie         2019       Rian Johnson
# 3      680    movie         1994  Quentin Tarantino
# 4    27205    movie         2010  Christopher Nolan

# %%
# Check function
def create_film_df(df):
    film_languages = []
    film_genres = []
    for x in range(0, len(df['tmdb_id'])):
        try: 
            id_num = df.loc[x, 'tmdb_id']

            movie = tmdb.Movies(id_num)
            response = movie.info()
    
            df.loc[x, 'run_time'] = response['runtime']
            df.loc[x, 'vote_average'] = response['vote_average']
            df.loc[x, 'tagline'] = response['tagline']
            df.loc[x, 'overview'] = response['overview']

            # Make list of genres
            g = response['genres']
            genres = []
            for y in range(0, len(g)):
                s = list(g[y].values())
                genres.append(s[1])
            film_genres.append(genres)
    
            # Make list of language
            l = response['spoken_languages']
            lang = []
            for y in range(0, len(l)):
                s = list(l[y].values())
                lang.append(s[0])
            film_languages.append(lang)
    
        except:
            df.loc[x, 'run_time'] = 'None'
            df.loc[x, 'vote_average'] = 'None'
            df.loc[x, 'tagline'] = 'None'
            df.loc[x, 'overview'] = 'None'
            film_languages.append('None')
            film_genres.append('None')

    df['languages'] = film_languages

    df['genres'] = film_genres

    df.head()
    
    return df

# %%
create_film_df(test)
# Out:
#                                 film_name   lb_id  \
# 0                                Parasite  426406
# 1                                   Joker  406775
# 2                              Knives Out  475370
# 3                            Pulp Fiction   51444
# 4                               Inception   34722
# 5                                 Get Out  353117
# 6          Once Upon a Time… in Hollywood  397859
# 7                               Lady Bird  326279
# 8       Spider-Man: Into the Spider-Verse  251943
# 9                               Midsommar  459564
# 10                             Fight Club   51568
# 11                        The Dark Knight   51896
# 12                             La La Land  240344
# 13               The Grand Budapest Hotel   95113
# 14                           Interstellar  117621
# 15                            Jojo Rabbit  444600
# 16                            Baby Driver  268950
# 17                                    Her  114564
# 18                   Inglourious Basterds   41352
# 19                            The Shining   51432
# 20                               Whiplash  171384
# 21                          Black Panther  209383
# 22                The Wolf of Wall Street   86114
# 23                 Avengers: Infinity War  226661
# 24                             Uncut Gems  404266
# 25                              Gone Girl  149857
# 26                      Avengers: Endgame  226660
# 45         1995         David Fincher     127.0           8.3
# 46         2019          Jordan Peele     116.0           7.0
# 47         2017      Denis Villeneuve     164.0           7.5
# 48         2020           Pete Docter     101.0           8.2
# 49         2017         Taika Waititi     131.0           7.6
#
#                                               tagline  \
# 0                         Act like you own the place.
# 1                                Put on a happy face.
# 2               Hell, any of them could have done it.
# 3   Just because you are a character doesn't mean ...
# 4                Your mind is the scene of the crime.
# 5   Just because you're invited, doesn't mean you'...
# 6          In this town, it can all change… like that
# 7                                      Fly Away Home.
# 8                        More Than One Wears the Mask
# 9                          Let the festivities begin.
# 10                            Mischief. Mayhem. Soap.
# 11                                    Why So Serious?
# 12                     Here's to the fools who dream.
# 13  A murder case of Madam D. With enormous wealth...
# 14  Mankind was born on Earth. It was never meant ...
# 15                               An anti-hate satire.
# 16                  All you need is one killer track.
# 17                           A Spike Jonze Love Story
# 18        Once upon a time in Nazi occupied France...
# 19  He came as the caretaker, but this hotel had i...
# 20    The road to greatness can take you to the edge.
# 21                                Long live the king.
# 22                                EARN. SPEND. PARTY.
# 23              An entire universe. Once and for all.
# 24                                 This is how I win.
# 25        You don't know what you've got 'til it's...
# 26                    Part of the journey is the end.
# 27                 There is enchantment in the light.
# 28                                 What a Lovely Day.
# 29                                 Why are they here?
# 30                                     Own your story
# 31
# 32                                  Time is the enemy
# 33  You can erase someone from your mind. Getting ...
# 34                      Is it better to speak or die?
# 35                    This is the story of a lifetime
# 36        Life, liberty and the pursuit of vengeance.
# 37  You don't get to 500 million friends without m...
# 38               Where there's a love, there's a way.
# 39                  Every family tree hides a secret.
# 40                        All heroes start somewhere.
# 41  To enter the mind of a killer she must challen...
# 42                                Survival is Victory
# 43                      A roaring rampage of revenge.
# 44                         An offer you can't refuse.
# 45              Seven deadly sins. Seven ways to die.
# 46                                     Watch yourself
# 47        The key to the future is finally unearthed.
# 48         Is all this living really worth dying for?
# 49                             No Hammer. No Problem.
#
#                                              overview  \
# 0   All unemployed, Ki-taek's family takes peculia...
# 1   During the 1980s, a failed stand-up comedian i...
# 2   When renowned crime novelist Harlan Thrombey i...
# 3   A burger-loving hit man, his philosophical par...
# 4   Cobb, a skilled thief who commits corporate es...
# 5   Chris and his girlfriend Rose go upstate to vi...
# 6   Los Angeles, 1969. TV star Rick Dalton, a stru...
# 7   Lady Bird McPherson, a strong willed, deeply o...
# 8   Miles Morales is juggling his life between bei...
# 9   Several friends travel to Sweden to study as a...
# 10  A ticking-time-bomb insomniac and a slippery s...
# 11  Batman raises the stakes in his war on crime. ...
# 12  Mia, an aspiring actress, serves lattes to mov...
# 13  The Grand Budapest Hotel tells of a legendary ...
# 14  The adventures of a group of explorers who mak...
# 15  A World War II satire that follows a lonely Ge...
# 16  After being coerced into working for a crime b...
# 17  In the not so distant future, Theodore, a lone...
# 18  In Nazi-occupied France during World War II, a...
# 19  Jack Torrance accepts a caretaker job at the O...
# 20  Under the direction of a ruthless instructor, ...
# 12                    [Comedy, Drama, Romance, Music]
# 13                                    [Comedy, Drama]
# 14                [Adventure, Drama, Science Fiction]
# 15                               [Comedy, War, Drama]
# 16                                    [Action, Crime]
# 17                  [Romance, Science Fiction, Drama]
# 18                     [Drama, Action, Thriller, War]
# 19                                 [Horror, Thriller]
# 20                                     [Drama, Music]
# 21               [Action, Adventure, Science Fiction]
# 22                             [Crime, Drama, Comedy]
# 23               [Adventure, Action, Science Fiction]
# 24                           [Crime, Thriller, Drama]
# 25                         [Mystery, Thriller, Drama]
# 26               [Adventure, Science Fiction, Action]
# 27                 [Drama, Fantasy, Thriller, Horror]
# 28               [Action, Adventure, Science Fiction]
# 29                  [Drama, Science Fiction, Mystery]
# 30                                   [Drama, Romance]
# 31                       [Animation, Family, Fantasy]
# 32                     [War, Drama, Action, Thriller]
# 33                  [Science Fiction, Drama, Romance]
# 34                                   [Romance, Drama]
# 35                                            [Drama]
# 36                                   [Drama, Western]
# 37                                            [Drama]
# 38                                            [Drama]
# 39                        [Horror, Mystery, Thriller]
# 40               [Action, Science Fiction, Adventure]
# 41                   [Crime, Drama, Thriller, Horror]
# 42                               [War, Action, Drama]
# 43                                    [Action, Crime]
# 44                                     [Drama, Crime]
# 45                         [Crime, Mystery, Thriller]
# 46                        [Thriller, Horror, Mystery]
# 47                           [Science Fiction, Drama]
# 48        [Family, Animation, Music, Fantasy, Comedy]
# 49  [Action, Adventure, Comedy, Fantasy, Science F...

# %%
df = create_film_df(film_df)

# %%
for x in range(0, len(film_df['tmdb_id'])):
    if film_df.iloc[x]['movie_tv'] == 'movie':
        id_num = film_df.iloc[x]['tmdb_id']

        movie = tmdb.Movies(id_num)
        response = movie.info

        try:
            # Make list of language
            l = movie.spoken_languages
            lang = []
            for x in range(0, len(l)):
                s = list(l[x].values())
                lang.append(s[0])
            film_df.iloc[x]['language'] = lang

            # Make list of genres
            g = movie.genres
            genres = []
            for x in range(0, len(g)):
                s = list(g[x].values())
                genres.append(s[1])
            film_df.iloc[x]['genres'] = genres


            film_df.iloc[x]['average_rating'] = movie.vote_average
            film_df.iloc[x]['tagline'] = movie.tagline
            film_df.iloc[x]['runtime'] = movie.runtime
            film_df.iloc[x]['overview'] = movie.overview
        
    else: 
        id_num = film_df.iloc[x]['tmdb_id']

        tv = tmdb.TVMovie(id_num)

        # Make list of language
        l = tv.spoken_languages
        lang = []
        for x in range(0, len(l)):
            s = list(l[x].values())
            lang.append(s[0])
        film_df.iloc[x]['language'] = lang

        # Make list of genres
        g = tv.genres
        genres = []
        for x in range(0, len(g)):
            s = list(g[x].values())
            genres.append(s[1])
        film_df.iloc[x]['genres'] = genres


        film_df.iloc[x]['average_rating'] = tv.vote_average
        film_df.iloc[x]['tagline'] = tv.tagline
        film_df.iloc[x]['runtime'] = tv.runtime
        film_df.iloc[x]['overview'] = tv.overview

# %%
# save df_film to computer
df.to_csv(r'panda_dataframes/letterboxd_film_data.csv', index = False)
